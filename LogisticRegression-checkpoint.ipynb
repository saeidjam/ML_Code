# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing 
import matplotlib.pyplot as plt
plt.rc("font", size= 14)
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
import seaborn as sns
sns.set(style = "white", color_codes = True)

# %%
data = pd.read_csv("C:\\Users\\Saeid\\OneDrive\\Desktop\\banking.txt")
data = data.dropna()
print(data.shape)
print(list(data.columns))
# Out:
# (41188, 21)
# ['age', 'job', 'marital', 'education', 'default', 'housing', 'loan', 'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays', 'previous', 'poutcome', 'emp_var_rate', 'cons_price_idx', 'cons_conf_idx', 'euribor3m', 'nr_employed', 'y']

# %%
data.head()
# Out:
#    age          job  marital          education  default housing loan  \
# 0   44  blue-collar  married           basic.4y  unknown     yes   no
# 1   53   technician  married            unknown       no      no   no
# 2   28   management   single  university.degree       no     yes   no
# 3   39     services  married        high.school       no      no   no
# 4   55      retired  married           basic.4y       no     yes   no
#
#     contact month day_of_week  ...  campaign  pdays  previous     poutcome  \
# 0  cellular   aug         thu  ...         1    999         0  nonexistent
# 1  cellular   nov         fri  ...         1    999         0  nonexistent
# 2  cellular   jun         thu  ...         3      6         2      success
# 3  cellular   apr         fri  ...         2    999         0  nonexistent
# 4  cellular   aug         fri  ...         1      3         1      success
#
#   emp_var_rate  cons_price_idx  cons_conf_idx  euribor3m  nr_employed  y
# 0          1.4          93.444          -36.1      4.963       5228.1  0
# 1         -0.1          93.200          -42.0      4.021       5195.8  0
# 2         -1.7          94.055          -39.8      0.729       4991.6  1
# 3         -1.8          93.075          -47.1      1.405       5099.1  0
# 4         -2.9          92.201          -31.4      0.869       5076.2  1
#
# [5 rows x 21 columns]

# %%
data['education'].unique()
# Out:
# array(['basic.4y', 'unknown', 'university.degree', 'high.school',
#        'basic.9y', 'professional.course', 'basic.6y', 'illiterate'],
#       dtype=object)

# %%
data['education']= np.where(data['education'] == 'basic.4y', 'Basic', data['education'])
data['education']= np.where(data['education'] == 'basic.6y', 'Basic', data['education'])
data['education']= np.where(data['education'] == 'basic.9y', 'Basic', data['education'])

# %%
data ['education'].unique()
# Out:
# array(['Basic', 'unknown', 'university.degree', 'high.school',
#        'professional.course', 'illiterate'], dtype=object)

# %%
data ['y'].value_counts()
# Out:
# 0    36548
# 1     4640
# Name: y, dtype: int64

# %%
sns.countplot(x= 'y', data=data, palette='hls')
plt.show()

# %%
count_no_sub = len(data[data['y'] == 0])
count_sub = len(data[data['y'] == 1])
pct_of_no_sub = count_no_sub / (count_no_sub + count_sub)
print("percentage of non-subscribe:", pct_of_no_sub)
pct_of_sub = count_sub / (count_no_sub + count_sub)
print("percentage of subscribe:", pct_of_no_sub)
# Out:
# percentage of non-subscribe: 0.8873458288821987
# percentage of subscribe: 0.8873458288821987

# %%
data.describe()
# Out:
#                age      duration      campaign         pdays      previous  \
# count  41188.00000  41188.000000  41188.000000  41188.000000  41188.000000
# mean      40.02406    258.285010      2.567593    962.475454      0.172963
# std       10.42125    259.279249      2.770014    186.910907      0.494901
# min       17.00000      0.000000      1.000000      0.000000      0.000000
# 25%       32.00000    102.000000      1.000000    999.000000      0.000000
# 50%       38.00000    180.000000      2.000000    999.000000      0.000000
# 75%       47.00000    319.000000      3.000000    999.000000      0.000000
# max       98.00000   4918.000000     56.000000    999.000000      7.000000
#
#        emp_var_rate  cons_price_idx  cons_conf_idx     euribor3m  \
# count  41188.000000    41188.000000   41188.000000  41188.000000
# mean       0.081886       93.575664     -40.502600      3.621291
# std        1.570960        0.578840       4.628198      1.734447
# min       -3.400000       92.201000     -50.800000      0.634000
# 25%       -1.800000       93.075000     -42.700000      1.344000
# 50%        1.100000       93.749000     -41.800000      4.857000
# 75%        1.400000       93.994000     -36.400000      4.961000
# max        1.400000       94.767000     -26.900000      5.045000
#
#         nr_employed             y
# count  41188.000000  41188.000000
# mean    5167.035911      0.112654
# std       72.251528      0.316173
# min     4963.600000      0.000000
# 25%     5099.100000      0.000000
# 50%     5191.000000      0.000000
# 75%     5228.100000      0.000000
# max     5228.100000      1.000000

# %%
data.groupby('y').mean()
# Out:
#          age    duration  campaign       pdays  previous  emp_var_rate  \
# y
# 0  39.911185  220.844807  2.633085  984.113878  0.132374      0.248875
# 1  40.913147  553.191164  2.051724  792.035560  0.492672     -1.233448
#
#    cons_price_idx  cons_conf_idx  euribor3m  nr_employed
# y
# 0       93.603757     -40.593097   3.811491  5176.166600
# 1       93.354386     -39.789784   2.123135  5095.115991

# %%
data.groupby('job').mean()
# Out:
#                      age    duration  campaign       pdays  previous  \
# job
# admin.         38.187296  254.312128  2.623489  954.319229  0.189023
# blue-collar    39.555760  264.542360  2.558461  985.160363  0.122542
# entrepreneur   41.723214  263.267857  2.535714  981.267170  0.138736
# housemaid      45.500000  250.454717  2.639623  960.579245  0.137736
# management     42.362859  257.058140  2.476060  962.647059  0.185021
# retired        62.027326  273.712209  2.476744  897.936047  0.327326
# self-employed  39.949331  264.142153  2.660802  976.621393  0.143561
# services       37.926430  258.398085  2.587805  979.974049  0.154951
# student        25.894857  283.683429  2.104000  840.217143  0.524571
# technician     38.507638  250.232241  2.577339  964.408127  0.153789
# unemployed     39.733728  249.451677  2.564103  935.316568  0.199211
# unknown        45.563636  239.675758  2.648485  938.727273  0.154545
#
#                emp_var_rate  cons_price_idx  cons_conf_idx  euribor3m  \
# job
# admin.             0.015563       93.534054     -40.245433   3.550274
# blue-collar        0.248995       93.656656     -41.375816   3.771996
# entrepreneur       0.158723       93.605372     -41.283654   3.791120
# housemaid          0.433396       93.676576     -39.495283   4.009645
# management        -0.012688       93.522755     -40.489466   3.611316
# retired           -0.698314       93.430786     -38.573081   2.770066
# self-employed      0.094159       93.559982     -40.488107   3.689376
# services           0.175359       93.634659     -41.290048   3.699187
# student           -1.408000       93.331613     -40.187543   1.884224
# technician         0.274566       93.561471     -39.927569   3.820401
# unemployed        -0.111736       93.563781     -40.007594   3.466583
# unknown            0.357879       93.718942     -38.797879   3.949033
#
#                nr_employed         y
# job
# admin.         5164.125350  0.129726
# blue-collar    5175.615150  0.068943
# entrepreneur   5176.313530  0.085165
# housemaid      5179.529623  0.100000
# management     5166.650513  0.112175
# retired        5122.262151  0.252326
# self-employed  5170.674384  0.104856
# services       5171.600126  0.081381
# student        5085.939086  0.314286
# technician     5175.648391  0.108260
# unemployed     5157.156509  0.142012
# unknown        5172.931818  0.112121

# %%
pd.crosstab(data.job, data.y).plot(kind = 'bar')
plt.title('purchase freqency for job title')
plt.xlabel('job')
plt.xlabel('frequency of purchase')
# Out:
# Text(0.5, 0, 'frequency of purchase')

# %%
table = pd.crosstab(data.marital, data.y)
table.div(table.sum(1).astype('float'), axis=0).plot(kind='bar', stacked = True)
plt.title('stacked bar chart')
plt.xlabel('martial status')
plt.ylabel('Proportion of customers')
# Out:
# Text(0, 0.5, 'Proportion of customers')

# %%
subscribed = data [data['y']== 1].sample(n= 4640)
non_subscribed = data [data['y']== 0].sample(n= 4640)

# %%
subscribed.head()
# Out:
#        age            job   marital            education  default housing  \
# 3758    29  self-employed   married  professional.course  unknown     yes
# 17036   38     technician   married  professional.course  unknown      no
# 13473   48    blue-collar  divorced  professional.course       no      no
# 7745    65        retired    single    university.degree       no      no
# 39864   34    blue-collar   married                Basic       no      no
#
#       loan    contact month day_of_week  ...  campaign  pdays  previous  \
# 3758   yes   cellular   jul         wed  ...         2    999         0
# 17036   no   cellular   nov         wed  ...         1    999         0
# 13473   no   cellular   nov         mon  ...         1    999         0
# 7745    no   cellular   nov         thu  ...         2      3         2
# 39864   no  telephone   jun         tue  ...         2    999         0
#
#           poutcome emp_var_rate  cons_price_idx  cons_conf_idx  euribor3m  \
# 3758   nonexistent          1.4          93.918          -42.7      4.963
# 17036  nonexistent         -0.1          93.200          -42.0      4.120
# 13473  nonexistent         -0.1          93.200          -42.0      4.191
# 7745       success         -3.4          92.649          -30.1      0.714
# 39864  nonexistent          1.4          94.465          -41.8      4.864
#
#        nr_employed  y
# 3758        5228.1  1
# 17036       5195.8  1
# 13473       5195.8  1
# 7745        5017.5  1
# 39864       5228.1  1
#
# [5 rows x 21 columns]

# %%
non_subscribed.head()
# Out:
#        age          job   marital    education  default housing loan  \
# 13339   50  blue-collar   married      unknown  unknown     yes   no
# 33898   48  blue-collar   married        Basic       no      no   no
# 33144   51       admin.  divorced  high.school       no      no   no
# 2270    59  blue-collar   married        Basic       no      no   no
# 37525   45       admin.   married  high.school       no     yes   no
#
#          contact month day_of_week  ...  campaign  pdays  previous  \
# 13339   cellular   jul         thu  ...         2    999         0
# 33898  telephone   jun         mon  ...         1    999         0
# 33144   cellular   aug         tue  ...         1      6         2
# 2270    cellular   may         thu  ...         2    999         1
# 37525   cellular   may         thu  ...         2    999         1
#
#           poutcome emp_var_rate  cons_price_idx  cons_conf_idx  euribor3m  \
# 13339  nonexistent          1.4          93.918          -42.7      4.958
# 33898  nonexistent          1.4          94.465          -41.8      4.961
# 33144      failure         -2.9          92.201          -31.4      0.838
# 2270       failure         -1.8          92.893          -46.2      1.327
# 37525      failure         -1.8          92.893          -46.2      1.327
#
#        nr_employed  y
# 13339       5228.1  0
# 33898       5228.1  0
# 33144       5076.2  0
# 2270        5099.1  0
# 37525       5099.1  0
#
# [5 rows x 21 columns]

# %%
new_dataset = subscribed.append(non_subscribed)

# %%
new_dataset
# Out:
#        age            job   marital            education  default  housing  \
# 3758    29  self-employed   married  professional.course  unknown      yes
# 17036   38     technician   married  professional.course  unknown       no
# 13473   48    blue-collar  divorced  professional.course       no       no
# 7745    65        retired    single    university.degree       no       no
# 39864   34    blue-collar   married                Basic       no       no
# 16371   52  self-employed   married                Basic  unknown       no
# 8905    42       services   married          high.school       no      yes
# 24883   53         admin.  divorced    university.degree       no       no
# 37324   38      housemaid  divorced    university.degree       no       no
# 40337   60        retired   married          high.school  unknown      yes
# 26504   27         admin.    single    university.degree       no      yes
# 37904   52     management   married    university.degree       no      yes
# 40804   73        retired  divorced                Basic       no       no
# 34616   30    blue-collar   married  professional.course       no       no
# 16808   17        student    single                Basic       no  unknown
# 29474   53    blue-collar   married                Basic  unknown       no
# 646     29    blue-collar   married                Basic       no       no
# 20157   59     technician   married                Basic  unknown      yes
# 8501    30         admin.    single    university.degree       no       no
# 12      55     management   married    university.degree       no       no
# 19280   38     technician   married          high.school       no      yes
# 35042   26        student    single          high.school       no       no
# 1657    32         admin.    single    university.degree       no       no
# 2076    48         admin.   married                Basic       no      yes
# 22262   24        student    single              unknown       no      yes
# 10884   33         admin.   married    university.degree       no      yes
# 12860   50         admin.   married    university.degree       no      yes
# 17203   26        student    single                Basic       no      yes
# 17739   31         admin.    single    university.degree       no      yes
# 11933   30         admin.    single          high.school       no       no
# ...    ...            ...       ...                  ...      ...      ...
# 11433   29         admin.    single                Basic  unknown       no
# 36000   53       services   married          high.school  unknown       no
# 8699    40         admin.   married          high.school       no       no
# 16054   34        unknown   married                Basic  unknown      yes
# 5179    45     management    single                Basic       no      yes
# 31193   32     technician   married  professional.course  unknown       no
# 20290   37     technician   married          high.school       no       no
# 35144   35         admin.   married          high.school       no      yes
# 3270    48     technician   married          high.school       no       no
# 10677   60    blue-collar   married              unknown  unknown      yes
# 34331   30         admin.   married          high.school       no      yes
# 6689    55    blue-collar   married                Basic       no       no
# 25971   35     technician    single                Basic       no       no
# 1359    33         admin.    single    university.degree  unknown  unknown
# 33083   42    blue-collar   married                Basic  unknown      yes
# 24733   57        retired   married                Basic       no      yes
# 13802   47   entrepreneur   married    university.degree       no      yes
# 37217   52    blue-collar   married                Basic  unknown       no
# 11157   40     management   married    university.degree       no      yes
# 28922   46       services  divorced                Basic       no      yes
# 23051   39       services   married          high.school       no       no
# 16349   41     management   married    university.degree       no       no
# 24921   31    blue-collar    single          high.school       no       no
# 35860   28  self-employed    single    university.degree       no      yes
# 8130    46        unknown   married                Basic  unknown       no
# 30863   32       services   married              unknown       no       no
# 13245   43       services   married          high.school  unknown  unknown
# 34148   30     technician   married  professional.course       no      yes
# 16100   36       services    single                Basic       no      yes
# 23697   32    blue-collar   married                Basic  unknown       no
#
#           loan    contact month day_of_week  ...  campaign  pdays  previous  \
# 3758       yes   cellular   jul         wed  ...         2    999         0
# 17036       no   cellular   nov         wed  ...         1    999         0
# 13473       no   cellular   nov         mon  ...         1    999         0
# 7745        no   cellular   nov         thu  ...         2      3         2
# 39864       no  telephone   jun         tue  ...         2    999         0
# 16371      yes  telephone   jun         fri  ...         2    999         0
# 8905        no   cellular   apr         thu  ...         1    999         0
# 24883       no   cellular   mar         thu  ...         1    999         0
# 37324       no   cellular   nov         wed  ...         2    999         0
# 40337       no  telephone   may         fri  ...         6    999         0
# 26504      yes   cellular   jun         mon  ...         1    999         0
# 37904       no   cellular   nov         wed  ...         3    999         0
# 40804      yes   cellular   apr         tue  ...         1    999         0
# 34616       no   cellular   may         fri  ...         4    999         1
# 16808  unknown   cellular   aug         fri  ...         2    999         1
# 29474       no   cellular   aug         fri  ...         1    999         0
# 646         no   cellular   may         thu  ...         2    999         0
# 20157      yes   cellular   jul         thu  ...         1    999         0
# 8501        no   cellular   jun         tue  ...         2    999         0
# 12          no   cellular   aug         mon  ...         3    999         0
# 19280       no   cellular   jul         tue  ...         8    999         0
# 35042       no  telephone   jun         mon  ...         1    999         0
# 1657        no   cellular   jun         fri  ...         1    999         0
# 2076        no  telephone   mar         mon  ...         2    999         0
# 22262       no   cellular   oct         fri  ...         1    999         0
# 10884       no   cellular   may         mon  ...         1      3         2
# 12860       no   cellular   jun         fri  ...         7    999         1
# 17203       no   cellular   mar         mon  ...         3    999         0
# 17739       no   cellular   jul         wed  ...         2    999         0
# 11933       no   cellular   sep         fri  ...         3      6         1
# ...        ...        ...   ...         ...  ...       ...    ...       ...
# 11433       no  telephone   may         tue  ...         4    999         0
# 36000       no  telephone   may         thu  ...         4    999         0
# 8699        no  telephone   jun         thu  ...         2    999         0
# 16054       no  telephone   may         tue  ...         1    999         0
# 5179        no  telephone   jun         thu  ...         2    999         0
# 31193      yes   cellular   aug         thu  ...         1    999         0
# 20290       no   cellular   nov         tue  ...         1    999         0
# 35144       no   cellular   nov         thu  ...         2    999         0
# 3270       yes  telephone   may         tue  ...         1    999         0
# 10677       no   cellular   may         mon  ...         5    999         0
# 34331       no  telephone   nov         thu  ...         1    999         0
# 6689        no   cellular   jun         mon  ...         2    999         0
# 25971       no  telephone   nov         wed  ...         1    999         1
# 1359   unknown   cellular   aug         tue  ...         3    999         0
# 33083       no  telephone   may         mon  ...         5    999         0
# 24733       no  telephone   aug         mon  ...         1    999         0
# 13802       no  telephone   jun         mon  ...         3    999         0
# 37217       no   cellular   aug         fri  ...         2    999         0
# 11157       no   cellular   apr         mon  ...         2    999         1
# 28922       no   cellular   may         wed  ...         1    999         1
# 23051       no  telephone   jun         thu  ...         1    999         0
# 16349       no  telephone   may         fri  ...         4    999         0
# 24921       no   cellular   nov         wed  ...         1    999         0
# 35860       no   cellular   may         wed  ...         1    999         0
# 8130        no  telephone   may         fri  ...         1    999         0
# 30863       no  telephone   jun         mon  ...         4    999         0
# 13245  unknown  telephone   may         wed  ...         4    999         0
# 34148       no   cellular   jul         fri  ...         2    999         0
# 16100       no   cellular   may         fri  ...         3    999         1
# 23697       no   cellular   jul         mon  ...         5    999         0
#
#           poutcome emp_var_rate  cons_price_idx  cons_conf_idx  euribor3m  \
# 3758   nonexistent          1.4          93.918          -42.7      4.963
# 17036  nonexistent         -0.1          93.200          -42.0      4.120
# 13473  nonexistent         -0.1          93.200          -42.0      4.191
# 7745       success         -3.4          92.649          -30.1      0.714
# 39864  nonexistent          1.4          94.465          -41.8      4.864
# 16371  nonexistent          1.4          94.465          -41.8      4.967
# 8905   nonexistent         -1.8          93.075          -47.1      1.365
# 24883  nonexistent         -1.8          93.369          -34.8      0.654
# 37324  nonexistent         -1.1          94.767          -50.8      1.030
# 40337  nonexistent          1.1          93.994          -36.4      4.857
# 26504  nonexistent         -2.9          92.963          -40.8      1.266
# 37904  nonexistent         -0.1          93.200          -42.0      4.120
# 40804  nonexistent         -1.8          93.075          -47.1      1.423
# 34616      failure         -1.8          92.893          -46.2      1.250
# 16808      failure         -2.9          92.201          -31.4      0.869
# 29474  nonexistent          1.4          93.444          -36.1      4.966
# 646    nonexistent         -1.8          92.893          -46.2      1.327
# 20157  nonexistent          1.4          93.918          -42.7      4.962
# 8501   nonexistent         -2.9          92.963          -40.8      1.262
# 12     nonexistent          1.4          93.444          -36.1      4.965
# 19280  nonexistent          1.4          93.918          -42.7      4.961
# 35042  nonexistent          1.4          94.465          -41.8      4.961
# 1657   nonexistent         -2.9          92.963          -40.8      1.268
# 2076   nonexistent         -1.8          92.843          -50.0      1.811
# 22262  nonexistent         -3.4          92.431          -26.9      0.730
# 10884      success         -1.8          93.876          -40.0      0.685
# 12860      failure         -2.9          92.963          -40.8      1.268
# 17203  nonexistent         -1.8          92.843          -50.0      1.811
# 17739  nonexistent          1.4          93.918          -42.7      4.963
# 11933      success         -1.1          94.199          -37.5      0.883
# ...            ...          ...             ...            ...        ...
# 11433  nonexistent          1.1          93.994          -36.4      4.857
# 36000  nonexistent          1.1          93.994          -36.4      4.860
# 8699   nonexistent          1.4          94.465          -41.8      4.866
# 16054  nonexistent          1.1          93.994          -36.4      4.857
# 5179   nonexistent          1.4          94.465          -41.8      4.961
# 31193  nonexistent          1.4          93.444          -36.1      4.963
# 20290  nonexistent         -0.1          93.200          -42.0      4.153
# 35144  nonexistent         -0.1          93.200          -42.0      4.076
# 3270   nonexistent          1.1          93.994          -36.4      4.856
# 10677  nonexistent         -1.8          92.893          -46.2      1.354
# 34331  nonexistent         -0.1          93.200          -42.0      4.592
# 6689   nonexistent         -2.9          92.963          -40.8      1.215
# 25971      failure         -0.1          93.200          -42.0      4.120
# 1359   nonexistent          1.4          93.444          -36.1      4.963
# 33083  nonexistent          1.1          93.994          -36.4      4.857
# 24733  nonexistent          1.4          93.444          -36.1      4.970
# 13802  nonexistent          1.4          94.465          -41.8      4.960
# 37217  nonexistent          1.4          93.444          -36.1      4.964
# 11157      failure         -1.8          93.075          -47.1      1.405
# 28922      failure         -1.8          92.893          -46.2      1.334
# 23051  nonexistent          1.4          94.465          -41.8      4.866
# 16349  nonexistent          1.1          93.994          -36.4      4.859
# 24921  nonexistent         -0.1          93.200          -42.0      4.120
# 35860  nonexistent         -1.8          92.893          -46.2      1.334
# 8130   nonexistent          1.1          93.994          -36.4      4.855
# 30863  nonexistent          1.4          94.465          -41.8      4.961
# 13245  nonexistent          1.1          93.994          -36.4      4.858
# 34148  nonexistent          1.4          93.918          -42.7      4.957
# 16100      failure         -1.8          92.893          -46.2      1.313
# 23697  nonexistent          1.4          93.918          -42.7      4.960
#
#        nr_employed  y
# 3758        5228.1  1
# 17036       5195.8  1
# 13473       5195.8  1
# 7745        5017.5  1
# 39864       5228.1  1
# 16371       5228.1  1
# 8905        5099.1  1
# 24883       5008.7  1
# 37324       4963.6  1
# 40337       5191.0  1
# 26504       5076.2  1
# 37904       5195.8  1
# 40804       5099.1  1
# 34616       5099.1  1
# 16808       5076.2  1
# 29474       5228.1  1
# 646         5099.1  1
# 20157       5228.1  1
# 8501        5076.2  1
# 12          5228.1  1
# 19280       5228.1  1
# 35042       5228.1  1
# 1657        5076.2  1
# 2076        5099.1  1
# 22262       5017.5  1
# 10884       5008.7  1
# 12860       5076.2  1
# 17203       5099.1  1
# 17739       5228.1  1
# 11933       4963.6  1
# ...            ... ..
# 11433       5191.0  0
# 36000       5191.0  0
# 8699        5228.1  0
# 16054       5191.0  0
# 5179        5228.1  0
# 31193       5228.1  0
# 20290       5195.8  0
# 35144       5195.8  0
# 3270        5191.0  0
# 10677       5099.1  0
# 34331       5195.8  0
# 6689        5076.2  0
# 25971       5195.8  0
# 1359        5228.1  0
# 33083       5191.0  0
# 24733       5228.1  0
# 13802       5228.1  0
# 37217       5228.1  0
# 11157       5099.1  0
# 28922       5099.1  0
# 23051       5228.1  0
# 16349       5191.0  0
# 24921       5195.8  0
# 35860       5099.1  0
# 8130        5191.0  0
# 30863       5228.1  0
# 13245       5191.0  0
# 34148       5228.1  0
# 16100       5099.1  0
# 23697       5228.1  0
#
# [9280 rows x 21 columns]

# %%
new_dataset.shape
# Out:
# (9280, 21)

# %%
data = pd.get_dummies(new_dataset[['job','marital','education','default','housing','loan','contact','month','day_of_week','poutcome']])
data.head()
# Out:
#        job_admin.  job_blue-collar  job_entrepreneur  job_housemaid  \
# 3758            0                0                 0              0
# 17036           0                0                 0              0
# 13473           0                1                 0              0
# 7745            0                0                 0              0
# 39864           0                1                 0              0
#
#        job_management  job_retired  job_self-employed  job_services  \
# 3758                0            0                  1             0
# 17036               0            0                  0             0
# 13473               0            0                  0             0
# 7745                0            1                  0             0
# 39864               0            0                  0             0
#
#        job_student  job_technician  ...  month_oct  month_sep  \
# 3758             0               0  ...          0          0
# 17036            0               1  ...          0          0
# 13473            0               0  ...          0          0
# 7745             0               0  ...          0          0
# 39864            0               0  ...          0          0
#
#        day_of_week_fri  day_of_week_mon  day_of_week_thu  day_of_week_tue  \
# 3758                 0                0                0                0
# 17036                0                0                0                0
# 13473                0                1                0                0
# 7745                 0                0                1                0
# 39864                0                0                0                1
#
#        day_of_week_wed  poutcome_failure  poutcome_nonexistent  \
# 3758                 1                 0                     1
# 17036                1                 0                     1
# 13473                0                 0                     1
# 7745                 0                 0                     0
# 39864                0                 0                     1
#
#        poutcome_success
# 3758                  0
# 17036                 0
# 13473                 0
# 7745                  1
# 39864                 0
#
# [5 rows x 50 columns]

# %%
new_dataset.head()
# Out:
#        age            job   marital            education  default housing  \
# 3758    29  self-employed   married  professional.course  unknown     yes
# 17036   38     technician   married  professional.course  unknown      no
# 13473   48    blue-collar  divorced  professional.course       no      no
# 7745    65        retired    single    university.degree       no      no
# 39864   34    blue-collar   married                Basic       no      no
#
#       loan    contact month day_of_week  ...  campaign  pdays  previous  \
# 3758   yes   cellular   jul         wed  ...         2    999         0
# 17036   no   cellular   nov         wed  ...         1    999         0
# 13473   no   cellular   nov         mon  ...         1    999         0
# 7745    no   cellular   nov         thu  ...         2      3         2
# 39864   no  telephone   jun         tue  ...         2    999         0
#
#           poutcome emp_var_rate  cons_price_idx  cons_conf_idx  euribor3m  \
# 3758   nonexistent          1.4          93.918          -42.7      4.963
# 17036  nonexistent         -0.1          93.200          -42.0      4.120
# 13473  nonexistent         -0.1          93.200          -42.0      4.191
# 7745       success         -3.4          92.649          -30.1      0.714
# 39864  nonexistent          1.4          94.465          -41.8      4.864
#
#        nr_employed  y
# 3758        5228.1  1
# 17036       5195.8  1
# 13473       5195.8  1
# 7745        5017.5  1
# 39864       5228.1  1
#
# [5 rows x 21 columns]

# %%
new_dataset.drop(['job','marital','education','default','housing','loan','contact','month','day_of_week','poutcome'], axis=1, inplace=True)

# %%
new_dataset.head()
# Out:
#        age  duration  campaign  pdays  previous  emp_var_rate  cons_price_idx  \
# 3758    29       683         2    999         0           1.4          93.918
# 17036   38      1049         1    999         0          -0.1          93.200
# 13473   48       564         1    999         0          -0.1          93.200
# 7745    65        88         2      3         2          -3.4          92.649
# 39864   34       963         2    999         0           1.4          94.465
#
#        cons_conf_idx  euribor3m  nr_employed  y
# 3758           -42.7      4.963       5228.1  1
# 17036          -42.0      4.120       5195.8  1
# 13473          -42.0      4.191       5195.8  1
# 7745           -30.1      0.714       5017.5  1
# 39864          -41.8      4.864       5228.1  1

# %%
data_final = new_dataset.join(data)
data_final.head()
# Out:
#        age  duration  campaign  pdays  previous  emp_var_rate  cons_price_idx  \
# 3758    29       683         2    999         0           1.4          93.918
# 17036   38      1049         1    999         0          -0.1          93.200
# 13473   48       564         1    999         0          -0.1          93.200
# 7745    65        88         2      3         2          -3.4          92.649
# 39864   34       963         2    999         0           1.4          94.465
#
#        cons_conf_idx  euribor3m  nr_employed  ...  month_oct  month_sep  \
# 3758           -42.7      4.963       5228.1  ...          0          0
# 17036          -42.0      4.120       5195.8  ...          0          0
# 13473          -42.0      4.191       5195.8  ...          0          0
# 7745           -30.1      0.714       5017.5  ...          0          0
# 39864          -41.8      4.864       5228.1  ...          0          0
#
#        day_of_week_fri  day_of_week_mon  day_of_week_thu  day_of_week_tue  \
# 3758                 0                0                0                0
# 17036                0                0                0                0
# 13473                0                1                0                0
# 7745                 0                0                1                0
# 39864                0                0                0                1
#
#        day_of_week_wed  poutcome_failure  poutcome_nonexistent  \
# 3758                 1                 0                     1
# 17036                1                 0                     1
# 13473                0                 0                     1
# 7745                 0                 0                     0
# 39864                0                 0                     1
#
#        poutcome_success
# 3758                  0
# 17036                 0
# 13473                 0
# 7745                  1
# 39864                 0
#
# [5 rows x 61 columns]

# %%
y = ['y']
x = [i for i in data_final if i not in y]

# %%
from sklearn import datasets
from sklearn.feature_selection import RFE
logreg =LogisticRegression()
rfe = RFE(logreg, 18)
rfe = rfe.fit(data_final[x],data_final[y])
print(rfe.support_)
print(rfe.ranking_)
# Out:
# C:\Users\Saeid\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Saeid\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\Saeid\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\Saeid\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\Saeid\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\Saeid\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\Saeid\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\Saeid\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\Saeid\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\Saeid\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\Saeid\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\Saeid\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\Saeid\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\Saeid\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\Saeid\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\Saeid\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\Saeid\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\Saeid\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\Saeid\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\Saeid\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\Saeid\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\Saeid\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\Saeid\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\Saeid\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\Saeid\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\Saeid\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\Saeid\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\Saeid\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\Saeid\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\Saeid\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\Saeid\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\Saeid\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\Saeid\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\Saeid\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\Saeid\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\Saeid\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\Saeid\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\Saeid\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# [False False False False  True False False False  True False False False
#  False False False  True False False  True False False False False False
#  False False False False  True False False False  True  True False False
#  False False False False  True  True  True False  True False False  True
#   True  True  True False False  True False False False  True False  True]
# [43 38 20 42  1 10 24 37  1 31  7 18 14 26 16  1  6 15  1 32 17  4  8 13
#  21 41  3  5  1 33 36 11  1  1 28 39 29 25 40 30  1  1  1 23  1  2 12  1
#   1  1  1 22 35  1 27 34  9  1 19  1]
# C:\Users\Saeid\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\Saeid\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\Saeid\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\Saeid\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\Saeid\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\Saeid\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
print(list(data_final.columns))
# Out:
# ['age', 'duration', 'campaign', 'pdays', 'previous', 'emp_var_rate', 'cons_price_idx', 'cons_conf_idx', 'euribor3m', 'nr_employed', 'y', 'job_admin.', 'job_blue-collar', 'job_entrepreneur', 'job_housemaid', 'job_management', 'job_retired', 'job_self-employed', 'job_services', 'job_student', 'job_technician', 'job_unemployed', 'job_unknown', 'marital_divorced', 'marital_married', 'marital_single', 'marital_unknown', 'education_Basic', 'education_high.school', 'education_illiterate', 'education_professional.course', 'education_university.degree', 'education_unknown', 'default_no', 'default_unknown', 'housing_no', 'housing_unknown', 'housing_yes', 'loan_no', 'loan_unknown', 'loan_yes', 'contact_cellular', 'contact_telephone', 'month_apr', 'month_aug', 'month_dec', 'month_jul', 'month_jun', 'month_mar', 'month_may', 'month_nov', 'month_oct', 'month_sep', 'day_of_week_fri', 'day_of_week_mon', 'day_of_week_thu', 'day_of_week_tue', 'day_of_week_wed', 'poutcome_failure', 'poutcome_nonexistent', 'poutcome_success']

# %%
cols=["previous", "euribor3m", "job_blue-collar", "job_retired", "job_services", "job_student", "default_no", 
      "month_aug", "month_dec", "month_jul", "month_nov", "month_oct", "month_sep", "day_of_week_fri", "day_of_week_wed", 
      "poutcome_failure", "poutcome_nonexistent", "poutcome_success"] 
X= data_final[cols]
y = data_final['y']

# %%
seed = 7
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size= 0.3, random_state= seed)
y_train = y_train.ravel()

# %%
y_train
# Out:
# array([0, 1, 0, ..., 1, 0, 1], dtype=int64)

# %%
from pandas.plotting import scatter_matrix
import matplotlib.pyplot as plt
from sklearn import model_selection
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB

# %%
models = []
models.append(('LR', LogisticRegression()))
models.append(('KNN', KNeighborsClassifier()))
models.append(('DT', DecisionTreeClassifier()))
models.append(('SVM', SVC()))
models.append(('NB', GaussianNB()))
models.append(('LDA', LinearDiscriminantAnalysis()))

results = []
names = []
for name, model in models:
    kfold = model_selection.KFold(n_splits=10, random_state=seed)
    Results = model_selection.cross_val_score(model, X_train, y_train, cv=kfold, scoring= 'accuracy')
    results.append(Results)
    names.append(name)

# %%
fig = plt.figure()
fig.suptitle('Algorithm Comparison')
ax = fig.add_subplot(111)
plt.boxplot(results)
ax.set_xticklabels(names)
plt.show()

# %%
logreg = LogisticRegression()
logreg.fit(X_train, y_train)
y_pred = logreg.predict(X_test)
print('Accuracy:', logreg.score(X_test, y_test))
# Out:
# Accuracy: 0.7266522988505747
# C:\Users\Saeid\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
logit_roc_auc = roc_auc_score(y_test, logreg.predict(X_test))
fpr, tpr, thresholds = roc_curve(y_test, logreg.predict_proba(X_test)[:,1])
plt.figure()
plt.plot(fpr, tpr, label='Logistic Regression (area = %0.2f)' % logit_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('Log_ROC')
plt.show()
